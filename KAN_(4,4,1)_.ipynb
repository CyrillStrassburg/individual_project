# %%
import os
import sys
import Wind_KAN_
from kan import *
import importlib
from Wind_KAN_ import Wind_KAN

# %%
model = Wind_KAN(width=[4,4,1,1], grid=3, k=3, seed=42)
# Out:
# checkpoint directory created: ./model
# saving model version 0.0

# %%
winddata_path = os.path.join('..\\Liao_code','Task15_W_Zone6.csv')
model.get_winddataset(winddata_path)

# %%
model.save_act = True

# %%
dataset = model.dataset

# %%
model.fit_model()
# Out:
# | train_loss: 1.70e-01 | test_loss: 1.58e-01 | reg: 0.00e+00 | : 100%|█| 20/20 [00:39<00:00,  1.99s/
# saving model version 0.1
# {'train_loss': [array(0.19401707, dtype=float32),
#   array(0.18267927, dtype=float32),
#   array(0.17373824, dtype=float32),
#   array(0.17269488, dtype=float32),
#   array(0.17223708, dtype=float32),
#   array(0.17201662, dtype=float32),
#   array(0.17159173, dtype=float32),
#   array(0.17137113, dtype=float32),
#   array(0.17120749, dtype=float32),
#   array(0.17108166, dtype=float32),
#   array(0.1710425, dtype=float32),
#   array(0.1708706, dtype=float32),
#   array(0.17071182, dtype=float32),
#   array(0.1706121, dtype=float32),
#   array(0.17054713, dtype=float32),
#   array(0.17052007, dtype=float32),
#   array(0.17040029, dtype=float32),
#   array(0.17031123, dtype=float32),
#   array(0.17025144, dtype=float32),
#   array(0.17017269, dtype=float32)],
#  'test_loss': [array(0.17421232, dtype=float32),
#   array(0.16678786, dtype=float32),
#   array(0.1625487, dtype=float32),
#   array(0.15946676, dtype=float32),
#   array(0.15818529, dtype=float32),
#   array(0.15751076, dtype=float32),
#   array(0.15756322, dtype=float32),
#   array(0.15764508, dtype=float32),
#   array(0.15849936, dtype=float32),
#   array(0.15839587, dtype=float32),
#   array(0.15860954, dtype=float32),
#   array(0.1583497, dtype=float32),
#   array(0.15767409, dtype=float32),
#   array(0.15756217, dtype=float32),
#   array(0.15796414, dtype=float32),
#   array(0.15782547, dtype=float32),
#   array(0.15790768, dtype=float32),
#   array(0.15770933, dtype=float32),
#   array(0.15805022, dtype=float32),
#   array(0.15812615, dtype=float32)],
#  'reg': [array(0., dtype=float32),
#   array(0., dtype=float32),
#   array(0., dtype=float32),
#   array(0., dtype=float32),
#   array(0., dtype=float32),
#   array(0., dtype=float32),
#   array(0., dtype=float32),
#   array(0., dtype=float32),
#   array(0., dtype=float32),
#   array(0., dtype=float32),
#   array(0., dtype=float32),
#   array(0., dtype=float32),
#   array(0., dtype=float32),
#   array(0., dtype=float32),
#   array(0., dtype=float32),
#   array(0., dtype=float32),
#   array(0., dtype=float32),
#   array(0., dtype=float32),
#   array(0., dtype=float32),
#   array(0., dtype=float32)]}

# %%
model.plot_model()

# %%
model = model.prune()
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 model = model.prune()
#
# File c:\Users\Cyrill\Documents\semester_3\individual_project\.venv\lib\site-packages\kan\MultKAN.py:1785, in MultKAN.prune(self, node_th, edge_th)
#    1760 '''
#    1761 prune (both nodes and edges)
#    1762
#    (...)
#    1782 >>> model.plot()
#    1783 '''
#    1784 if self.acts == None:
# -> 1785     self.get_act()
#    1787 self = self.prune_node(node_th, log_history=False)
#    1788 #self.prune_node(node_th, log_history=False)
#
# File c:\Users\Cyrill\Documents\semester_3\individual_project\.venv\lib\site-packages\kan\MultKAN.py:2664, in MultKAN.get_act(self, x)
#    2662         x = self.cache_data
#    2663     else:
# -> 2664         raise Exception("missing input data x")
#    2665 save_act = self.save_act
#    2666 self.save_act = True
#
# Exception: missing input data x

# %%
for i in range(3):
    model.fit_model()
    model.prune()

model.plot_model()
# Out:
# steps:  100
# batchsize:  -1
# | train_loss: 1.69e-01 | test_loss: 1.58e-01 | reg: 1.76e+01 | : 100%|█| 100/100 [03:29<00:00,  2.09
# saving model version 0.2
# fitted
# saving model version 0.3
# steps:  100
# batchsize:  -1
# | train_loss: 1.69e-01 | test_loss: 1.59e-01 | reg: 1.61e+01 | : 100%|█| 100/100 [03:27<00:00,  2.08
# saving model version 0.3
# fitted
# saving model version 0.4
# steps:  100
# batchsize:  -1
# | train_loss: 1.69e-01 | test_loss: 1.59e-01 | reg: 1.60e+01 | : 100%|█| 100/100 [03:12<00:00,  1.92
# saving model version 0.4
# fitted
# saving model version 0.5

# %%
importlib.reload(Wind_KAN_)

# Loop through methods in the new class and update them on the existing instance
for method_name in dir(Wind_KAN_.Wind_KAN):
    if callable(getattr(Wind_KAN_.Wind_KAN, method_name)) and not method_name.startswith("__"):
        new_method = getattr(Wind_KAN_.Wind_KAN, method_name)
        setattr(model, method_name, new_method.__get__(model, model.__class__))

# %%
formula = model.get_formula()
# Out:
# fixing (0,0,0) with x, r2=0.8546891808509827, c=1
# fixing (0,0,1) with x, r2=0.00495229521766305, c=1
# fixing (0,0,2) with x, r2=0.9851382970809937, c=1
# fixing (0,0,3) with x, r2=0.0010433587012812495, c=1
# fixing (0,1,0) with x, r2=0.9293961524963379, c=1
# fixing (0,1,1) with x, r2=0.07492909580469131, c=1
# fixing (0,1,2) with x, r2=0.6202701330184937, c=1
# fixing (0,1,3) with x, r2=0.9011734127998352, c=1
# fixing (0,2,0) with cos, r2=0.995527982711792, c=2
# fixing (0,2,1) with gaussian, r2=0.9996793270111084, c=3
# fixing (0,2,2) with x, r2=0.8828687071800232, c=1
# fixing (0,2,3) with x, r2=0.8360211849212646, c=1
# fixing (0,3,0) with sin, r2=0.9990319609642029, c=2
# fixing (0,3,1) with x, r2=0.813108503818512, c=1
# fixing (0,3,2) with x, r2=0.9951316118240356, c=1
# fixing (0,3,3) with sin, r2=0.9922643899917603, c=2
# fixing (1,0,0) with x, r2=0.048414696007966995, c=1
# fixing (1,1,0) with x, r2=0.6761971712112427, c=1
# fixing (1,2,0) with x, r2=0.7506657838821411, c=1
# fixing (1,3,0) with cos, r2=0.9977284073829651, c=2
# fixing (2,0,0) with x, r2=0.9665695428848267, c=1
# saving model version 0.5
# 0.85*x_1 - 0.17*x_2 - 1.02*x_3 + 0.56*x_4 - 0.16*sin(2.64*x_4 - 8.4) + 0.13*cos(3.82*x_3 + 4.2) - 0.52*cos(0.07*x_1 + 3.45*x_2 - 6.17*x_3 + 0.62*sin(7.93*x_4 - 7.57) - 5.95) + 0.18 + 0.4*exp(-24.85*(0.3 - x_3)**2)

# %%
model.get_metrics()
# Out:
# rmse:  0.29349878
# mae:  0.24596293
# r2:  0.2626903588873649
# training time:  192.06573649999996
# (0.29349878, 0.24596293, 0.2626903588873649, 192.06573649999996)

# %%
model_metrics
# Out:
# (0.18620247, 0.1266131, 0.7032380947149325, 206.50262809999998)
